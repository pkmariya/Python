# %% [markdown]
# <a href="https://colab.research.google.com/github/pkmariya/Python/blob/master/MariyaMatPlotLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MatPlotLib

# %%
import matplotlib.pyplot as plt

# %%
# Simple line graph
x_val = [0, 1, 2]
y_val = [3, 4, 5]
plt.plot(x_val, y_val)
plt.show()

# %%
# a simple graph without x values; it assumes xticks as 0, 1, 2, .....
y_val = [3, 5, 7]
plt.plot(y_val)
plt.show()

# %%
# but y axis values are must; if we don't provide, it automatically assumes given values as y values and for x-axis it goes with default 0, 1, 2, ....
x_val = [3, 5, 8]
plt.plot(x_val,)
plt.show()
