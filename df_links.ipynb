# %% [markdown]
# <a href="https://colab.research.google.com/github/pkmariya/Python/blob/master/df_links.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/716/original/sales_dataset.csv?1651727754')

# %%
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df_new = df.copy()

# %%
df_new.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
highest_price = df_new['Price'].max()

# %%
highest_price
# Out:
# 38970.0

# %%
df_new['Sale_Price'] = df_new['Quantity'] * df_new['Price']

# %%
high_sp = df_new['Sale_Price'].max()

# %%
# df_new.groupby([‘Invoice’,‘Customer ID’]).agg({‘Sale_Price’:‘max’}).sort_values(by = [‘Sale_Price’], ascending = False)
df_new.groupby(['Invoice', 'Customer ID']).agg({'Sale_Price':'max'}).sort_values(by = ['Sale_Price'], ascending = False)
# Out:
#                      Sale_Price
# Invoice Customer ID
# 581483  16446.0       168469.60
# 541431  12346.0        77183.60
# 556444  15098.0        38970.00
# 530715  15838.0        15818.40
# 502263  12918.0        10953.50
# ...                         ...
# C502262 12918.0       -10953.50
# C512770 17399.0       -25111.09
# C556445 15098.0       -38970.00
# C541433 12346.0       -77183.60
# C581484 16446.0      -168469.60
#
# [44876 rows x 1 columns]

# %%
df1 = pd.read_csv('https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/715/original/sales_dataset.csv?1651726697')

# %%
df1.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
df1['Quantity'].max()
# Out:
# 80995

# %%
df1[df1['Quantity'] > 10000].sort_values('Quantity', ascending=False)
# Out:
#         Invoice StockCode                         Description  Quantity  \
# 1065882  581483     23843         PAPER CRAFT , LITTLE BIRDIE     80995
# 587080   541431     23166      MEDIUM CERAMIC TOP STORAGE JAR     74215
# 90857    497946     37410  BLACK AND WHITE PAISLEY FLOWER MUG     19152
# 127166   501534     21099         SET/6 STRAWBERRY PAPER CUPS     12960
# 127168   501534     21091         SET/6 WOODLAND PAPER PLATES     12960
# 127169   501534     21085           SET/6 WOODLAND PAPER CUPS     12744
# 1027583  578841     84826      ASSTD DESIGN 3D PAPER STICKERS     12540
# 127167   501534     21092       SET/6 STRAWBERRY PAPER PLATES     12480
# 192197   507637     84016          FLAG OF ST GEORGE CAR FLAG     10200
#
#                  InvoiceDate  Price  Customer ID         Country
# 1065882  2011-12-09 09:15:00   2.08      16446.0  United Kingdom
# 587080   2011-01-18 10:01:00   1.04      12346.0  United Kingdom
# ...

# %%
mod=df1.groupby('Description').sum()
mod[mod['Quantity']==max(mod['Quantity'])]
# Out:
#                                    Quantity   Price  Customer ID
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS    108545  298.18   14628933.0

# %%
df1.groupby('Description').agg({'Quantity':'sum'}).sort_values(by = 'Quantity', ascending = False)
# Out:
#                                     Quantity
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     108545
# WHITE HANGING HEART T-LIGHT HOLDER     93050
# ASSORTED COLOUR BIRD ORNAMENT          81306
# JUMBO BAG RED RETROSPOT                78090
# BROCADE RING PURSE                     70700
# ...                                      ...
# Unsaleable, destroyed.                -15644
# missing                               -16467
# printing smudges/thrown away          -19200
# given away                            -20000
# ?                                     -26757
#
# [5698 rows x 1 columns]

# %%
stock_df = pd.read_csv('https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/717/original/sales_dataset.csv?1651728217')

# %%
stock_df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
stock_df['StockCode'].nunique()
# Out:
# 5305

# %%
req=df1[df1['Country']=='United Kingdom']
req['StockCode'].nunique()
# Out:
# 5303

# %%
data = {'Row1': ['a', 'b', 'c'], 
        'Row2': [1, 2, 3]}
test_df = pd.DataFrame(data)
test_df
# Out:
#   Row1  Row2
# 0    a     1
# 1    b     2
# 2    c     3

# %%
imported = [1, 0, 0]
test_df['imported'] = imported
test_df
# Out:
#   Row1  Row2  imported
# 0    a     1         1
# 1    b     2         0
# 2    c     3         0

# %%
test_df.drop(['imported'], axis=1)
# Out:
#   Row1  Row2  imported2
# 0    a     1          1
# 1    b     2          0
# 2    c     3          0

# %%
test_df.drop(['imported2'], axis=1)
# Out:
#   Row1  Row2  imported
# 0    a     1         1
# 1    b     2         0
# 2    c     3         0

# %%
test_df
# Out:
#   Row1  Row2  imported2  imported
# 0    a     1          1         1
# 1    b     2          0         0
# 2    c     3          0         0

# %%
test_df.drop(['imported2'], axis=1)
# Out:
#   Row1  Row2  imported
# 0    a     1         1
# 1    b     2         0
# 2    c     3         0

# %%
test_df.drop(['imported'], axis=1)
# Out:
#   Row1  Row2  imported2
# 0    a     1          1
# 1    b     2          0
# 2    c     3          0

# %%
test_df
# Out:
#   Row1  Row2  imported2  imported
# 0    a     1          1         1
# 1    b     2          0         0
# 2    c     3          0         0

# %%
del test_df

# %%
test_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-0dcdcb22809f> in <module>
# ----> 1 test_df
#
# NameError: name 'test_df' is not defined

# %%
test_df = pd.DataFrame(data)
test_df
# Out:
#   Row1  Row2
# 0    a     1
# 1    b     2
# 2    c     3

# %%
test_df.insert(2, "imported2", imported)
test_df
# Out:
#   Row1  Row2  imported2
# 0    a     1          1
# 1    b     2          0
# 2    c     3          0

# %%
test_df.insert(2, "imported3", imported)
test_df
# Out:
#   Row1  Row2  imported3  imported2
# 0    a     1          1          1
# 1    b     2          0          0
# 2    c     3          0          0

# %%
# df10 = pd.DataFrame([[1, "Ram", "IT"], [2, "Shyam", "Ops"]], columns = ["emp_id", "name", "dept"])
df11 = pd.DataFrame([[1, "Ram", "IT"]], columns = ["emp_id", "name", "dept"])
df11
# Out:
#    emp_id name dept
# 0       1  Ram   IT

# %%
stock_df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country
# ...

# %%
stock_df['Country']
# Out:
# 0          United Kingdom
# 1          United Kingdom
# 2          United Kingdom
# 3          United Kingdom
# 4          United Kingdom
#                 ...
# 1067366            France
# 1067367            France
# 1067368            France
# 1067369            France
# 1067370            France
# Name: Country, Length: 1067371, dtype: object

# %%
stock_df.loc[:,'Country']
# Out:
# 0          United Kingdom
# 1          United Kingdom
# 2          United Kingdom
# 3          United Kingdom
# 4          United Kingdom
#                 ...
# 1067366            France
# 1067367            France
# 1067368            France
# 1067369            France
# 1067370            France
# Name: Country, Length: 1067371, dtype: object

# %%
model_df = pd.read_csv('https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/007/777/original/mtcars.csv?1658480283')

# %%
model_df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
model_df.loc[1:4, ['model', 'hp', 'drat']]
# Out:
#                model   hp  drat
# 1      Mazda RX4 Wag  110  3.90
# 2         Datsun 710   93  3.85
# 3     Hornet 4 Drive  110  3.08
# 4  Hornet Sportabout  175  3.15

# %%
name_data = {'name':["Ram","Shyam","Mukesh","Suresh"],'age':[10,18,60,50]}

# %%
a = pd.DataFrame(name_data)
a
# Out:
#      name  age
# 0     Ram   10
# 1   Shyam   18
# 2  Mukesh   60
# 3  Suresh   50

# %%
a['age']
# Out:
# 0    10
# 1    18
# 2    60
# 3    50
# Name: age, dtype: int64

# %%
change=lambda x: 'senior' if x>50 else 'adult' if x>=18 else 'kid'
a['age']=a.age.apply(change)
pd.DataFrame(a,columns=['name','age'])
a
# Out:
#      name     age
# 0     Ram     kid
# 1   Shyam   adult
# 2  Mukesh  senior
# 3  Suresh   adult
